# %%
# importing packages
from IPython.display import clear_output
import emoji
import time

def add_task():
    clear_output()
    print("             ---------------------------------------------------------------------------------------")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                             _________________________                                 |")
    print("            |                            | PRODUCTIVITY CALCULATOR |                                |")
    print("            |                             -------------------------                                 |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("             --------------------------------------------------------------------------------------- ")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                              <  TASK ADDED SUCCESSFULLY  >                            |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("             --------------------------------------------------------------------------------------- ")
    time.sleep(3)
    
def display_task():
    clear_output()
    print("             ---------------------------------------------------------------------------------------")
    print("            |                             _________________________                                 |")
    print("            |                            | PRODUCTIVITY CALCULATOR |                                |")
    print("            |                             -------------------------                                 |")
    print("            |                                  Displaying Task                                      |")
    print("             --------------------------------------------------------------------------------------- ")
    print("            |                                                                                       |")

    
def update_task():
    clear_output()
    print("             ---------------------------------------------------------------------------------------")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                             _________________________                                 |")
    print("            |                            | PRODUCTIVITY CALCULATOR |                                |")
    print("            |                             -------------------------                                 |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("             --------------------------------------------------------------------------------------- ")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                              <  TASK UPDATED SUCCESSFULLY  >                          |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("             --------------------------------------------------------------------------------------- ")
    time.sleep(3)
    
def delete_task():
    clear_output()
    print("             ---------------------------------------------------------------------------------------")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                             _________________________                                 |")
    print("            |                            | PRODUCTIVITY CALCULATOR |                                |")
    print("            |                             -------------------------                                 |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("             --------------------------------------------------------------------------------------- ")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                            <  TASK DELETED SUCCESSFULLY  >                            |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("             --------------------------------------------------------------------------------------- ")
    time.sleep(3)
    
     
def loading():
    clear_output()
    print("             ---------------------------------------------------------------------------------------")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                             _________________________                                 |")
    print("            |                            | PRODUCTIVITY CALCULATOR |                                |")
    print("            |                             -------------------------                                 |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("             --------------------------------------------------------------------------------------- ")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                    Loading...                                         |")
    print("            |                                                                                       |")
    print("            |                               \U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062                                                |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("             --------------------------------------------------------------------------------------- ")
    print("")
    print("")
    print("")
    print("")
    time.sleep(2)
    loading1()
    time.sleep(3)

def loading1():
    clear_output()
    print("             ---------------------------------------------------------------------------------------")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                             _________________________                                 |")
    print("            |                            | PRODUCTIVITY CALCULATOR |                                |")
    print("            |                             -------------------------                                 |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("             --------------------------------------------------------------------------------------- ")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                    Loading...                                         |")
    print("            |                                                                                       |")
    print("            |                               \U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062\U0001F062                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("            |                                                                                       |")
    print("             --------------------------------------------------------------------------------------- ")
    print("")
    print("")
    print("")
    print("")
